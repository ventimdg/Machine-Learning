# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score
from sklearn import svm
from scipy import io
import pandas as pd

# %%
#Question 2

def partition_mnist(data, labels):

    data = np.reshape(np.squeeze(data, axis = 1), (60000, 784))

    np.random.seed(10)
    permuted_data = np.random.permutation(data)

    np.random.seed(10)
    permuted_labels = np.random.permutation(labels)

    valiadation_data = permuted_data[:10000]
    training_data = permuted_data[10000:]

    valiadation_labels = permuted_labels[:10000]
    training_labels = permuted_labels[10000:]

    return training_data, training_labels, valiadation_data, valiadation_labels

def partition_spam(data, labels):

    validation_size = (int) ((len(data) * .2) // 1)

    np.random.seed(10)
    permuted_data = np.random.permutation(data)

    np.random.seed(10)
    permuted_labels = np.random.permutation(labels)

    valiadation_data = permuted_data[:validation_size]
    training_data = permuted_data[validation_size:]

    valiadation_labels = permuted_labels[:validation_size]
    training_labels = permuted_labels[validation_size:]

    return training_data, training_labels, valiadation_data, valiadation_labels

def partition_cifar10(data, labels):

    np.random.seed(10)
    permuted_data = np.random.permutation(data)

    np.random.seed(10)
    permuted_labels = np.random.permutation(labels)

    valiadation_data = permuted_data[:5000]
    training_data = permuted_data[5000:]

    valiadation_labels = permuted_labels[:5000]
    training_labels = permuted_labels[5000:]

    return training_data, training_labels, valiadation_data, valiadation_labels

# %%
#Question 3

#used https://stackoverflow.com/questions/33322349/set-legend-for-plot-with-several-lines-in-python to learn pyplot
def SVM_plots(samples, training, validation, dataset):
    plt.plot(samples, training, color = "red", label = "Training Data")
    plt.plot(samples, validation, color = "blue", label = "Validation Data")
    plt.ylabel("Accuracy")
    plt.xlabel("Samples")
    plt.title(dataset)
    plt.legend()
    plt.show()


#Used https://pythonprogramming.net/linear-svc-example-scikit-learn-svm-python/ to learn SVM
def SVM_MNIST():
    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/mnist-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    td, tl, vd, vl = partition_mnist(training_data, training_labels)
    clf = svm.SVC(kernel='linear')

    samples = [100, 200, 500, 1000, 2000, 5000, 10000]
    train_accuracy = []
    validation_accuracy = []

    X = td[:100]
    y = tl[:100]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:200]
    y = tl[:200]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:500]
    y = tl[:500]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:1000]
    y = tl[:1000]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:2000]
    y = tl[:2000]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:5000]
    y = tl[:5000]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)


    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    return validation_accuracy, train_accuracy, samples

def SVM_SPAM():
    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/spam-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    td, tl, vd, vl = partition_spam(training_data, training_labels)
    clf = svm.SVC(kernel='linear')

    samples = [100, 200, 500, 1000, 2000,len(td)]
    train_accuracy = []
    validation_accuracy = []

    X = td[:100]
    y = tl[:100]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:200]
    y = tl[:200]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:500]
    y = tl[:500]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:1000]
    y = tl[:1000]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:2000]
    y = tl[:2000]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td
    y = tl
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    return validation_accuracy, train_accuracy, samples

def SVM_CIFAR10():
    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/cifar10-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    samples = [100, 200, 500, 1000, 2000, 5000]
    train_accuracy = []
    validation_accuracy = []

    td, tl, vd, vl = partition_cifar10(training_data, training_labels)
    clf = svm.SVC(kernel='linear')

    X = td[:100]
    y = tl[:100]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:200]
    y = tl[:200]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:500]
    y = tl[:500]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:1000]
    y = tl[:1000]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:2000]
    y = tl[:2000]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    X = td[:5000]
    y = tl[:5000]
    clf.fit(X,y)

    validation_accuracy.append(clf.score(vd, vl))
    train_accuracy.append(clf.score(X, y))

    return validation_accuracy, train_accuracy, samples

MINST_val, MINST_train, MINST_samples = SVM_MNIST()
SVM_plots(MINST_samples, MINST_train, MINST_val, "MINST")
SPAM_val, SPAM_train, SPAM_samples = SVM_SPAM()
SVM_plots(SPAM_samples, SPAM_train, SPAM_val, "SPAM")
CIFAR_val, CIFAR_train, CIFAR_samples = SVM_CIFAR10()
SVM_plots(CIFAR_samples, CIFAR_train, CIFAR_val, "CIFAR10")

# %%
#Question 4
def SVM_MNIST_Tuning():
    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/mnist-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    td, tl, vd, vl = partition_mnist(training_data, training_labels)
    
    hyperperamter = .00001
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = .0001
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = .001
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = .01
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = .1
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = .2
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))


    hyperperamter = .5
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = .7
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = .9
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = .99
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = 1
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = 10
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = 100
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = 1000
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = 5000
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

    hyperperamter = 10000
    clf = svm.SVC(kernel='linear', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

SVM_MNIST_Tuning()
# Out:
# C Value: 1e-05, Accuracy: 0.1079
# C Value: 0.0001, Accuracy: 0.781
# C Value: 0.001, Accuracy: 0.9007
# C Value: 0.01, Accuracy: 0.9283
# C Value: 0.1, Accuracy: 0.9345
# C Value: 0.2, Accuracy: 0.9304
# C Value: 0.5, Accuracy: 0.9235
# C Value: 0.7, Accuracy: 0.9224
# C Value: 0.9, Accuracy: 0.9208
# C Value: 0.99, Accuracy: 0.92
# C Value: 1, Accuracy: 0.9199
# C Value: 10, Accuracy: 0.9155
# C Value: 100, Accuracy: 0.9155
# C Value: 1000, Accuracy: 0.9155
# C Value: 5000, Accuracy: 0.9155
# C Value: 10000, Accuracy: 0.9155

# %%
#Question 5
def SVM_SPAM_KFOLD(Cvals):

    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/spam-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    np.random.seed(10)
    permuted_data = np.random.permutation(training_data)
    np.random.seed(10)
    permuted_labels = np.random.permutation(training_labels)

    partition_size = len(permuted_data) // 5

    set1 = permuted_data[:partition_size]
    set2 = permuted_data[partition_size : 2*partition_size]
    set3 = permuted_data[2*partition_size : 3*partition_size]
    set4 = permuted_data[3*partition_size : 4*partition_size]
    set5 = permuted_data[4*partition_size:]

    datasets = [set1, set2, set3, set4, set5]

    label1 = permuted_labels[:partition_size]
    label2 = permuted_labels[partition_size : 2*partition_size]
    label3 = permuted_labels[2*partition_size : 3*partition_size]
    label4 = permuted_labels[3*partition_size : 4*partition_size]
    label5 = permuted_labels[4*partition_size:]

    labels = [label1, label2, label3, label4, label5]

    tempAccuracies = []
    finalAccuracies = []

    for c in Cvals:
        for i in range(5):
            clf = svm.SVC(kernel='linear', C = c)
            for j in range(5):
                if i == j:
                    continue
                else:
                    X = datasets[j]
                    y = labels[j]
                    clf.fit(X,y)
                tempAccuracies.append(clf.score(datasets[i], labels[i]))
        finalAccuracies.append(np.mean(tempAccuracies))
        tempAccuracies = []
    return finalAccuracies

C_values = [.00001, 0.0001,0.001,0.01,0.1,0.2, 0.5, 0.7, 0.9, 0.99, 1, 10, 100, 1000, 5000, 10000, 100000]
results = SVM_SPAM_KFOLD(C_values)

for i in range(len(results)):
    print("C Value: " + str(C_values[i]) + ", Accuracy: " + str(results[i]))
# Out:
# C Value: 1e-05, Accuracy: 0.7090048535334411
# C Value: 0.0001, Accuracy: 0.7090648055718104
# C Value: 0.001, Accuracy: 0.7281170757174165
# C Value: 0.01, Accuracy: 0.7614940105332
# C Value: 0.1, Accuracy: 0.7879786123254506
# C Value: 0.2, Accuracy: 0.7926537239108236
# C Value: 0.5, Accuracy: 0.7933127660550985
# C Value: 0.7, Accuracy: 0.7943907553383132
# C Value: 0.9, Accuracy: 0.7949898454442188
# C Value: 0.99, Accuracy: 0.7953495576744347
# C Value: 1, Accuracy: 0.795649031014423
# C Value: 10, Accuracy: 0.7970878799352862
# C Value: 100, Accuracy: 0.7983465858891835
# C Value: 1000, Accuracy: 0.798226825238374
# C Value: 5000, Accuracy: 0.7982269686643031
# C Value: 10000, Accuracy: 0.7982869207026724
# C Value: 100000, Accuracy: 0.7981670166259337

# %%
#Question 5
def SVM_SPAM_KFOLD(Cvals):

    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/spam-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    np.random.seed(10)
    permuted_data = np.random.permutation(training_data)
    np.random.seed(10)
    permuted_labels = np.random.permutation(training_labels)

    partition_size = len(permuted_data) // 5

    set1 = permuted_data[:partition_size]
    set2 = permuted_data[partition_size : 2*partition_size]
    set3 = permuted_data[2*partition_size : 3*partition_size]
    set4 = permuted_data[3*partition_size : 4*partition_size]
    set5 = permuted_data[4*partition_size:]

    datasets = [set1, set2, set3, set4, set5]

    fullsets = [np.concatenate((set2, set3, set4, set5)),
                np.concatenate((set1, set3, set4, set5)),
                np.concatenate((set1, set2, set4, set5)),
                np.concatenate((set1, set2, set3, set5)),
                np.concatenate((set1, set2, set3, set4))]
    
    label1 = permuted_labels[:partition_size]
    label2 = permuted_labels[partition_size : 2*partition_size]
    label3 = permuted_labels[2*partition_size : 3*partition_size]
    label4 = permuted_labels[3*partition_size : 4*partition_size]
    label5 = permuted_labels[4*partition_size:]


    labels = [label1, label2, label3, label4, label5]

    fulllabels = [np.concatenate((label2, label3, label4, label5)),
                  np.concatenate((label1, label3, label4, label5)),
                  np.concatenate((label1, label2, label4, label5)),
                  np.concatenate((label1, label2, label3, label5)),
                  np.concatenate((label1, label2, label3, label4))]

    tempAccuracies = []
    finalAccuracies = []

    for c in Cvals:
        for i in range(5):
            clf = svm.SVC(kernel='linear', C = c)
            clf.fit(fullsets[i], fulllabels[i])
            tempAccuracies.append(clf.score(datasets[i], labels[i]))
        finalAccuracies.append(np.mean(tempAccuracies))
        tempAccuracies = []
    return finalAccuracies

C_values = [.00001, 0.0001,0.001,0.01,0.1,0.2, 0.5, 0.7, 0.9, 0.99, 1, 10, 100, 1000]
results = SVM_SPAM_KFOLD(C_values)

for i in range(len(results)):
    print("C Value: " + str(C_values[i]) + ", Accuracy: " + str(results[i]))
# Out:
# C Value: 1e-05, Accuracy: 0.7090048535334412
# C Value: 0.0001, Accuracy: 0.7140368088304476
# C Value: 0.001, Accuracy: 0.7466340802955721
# C Value: 0.01, Accuracy: 0.7789881013849207
# C Value: 0.1, Accuracy: 0.7955268321228185
# C Value: 0.2, Accuracy: 0.799121659610111
# C Value: 0.5, Accuracy: 0.800799742980735
# C Value: 0.7, Accuracy: 0.8012787855839729
# C Value: 0.9, Accuracy: 0.8012793592876895
# C Value: 0.99, Accuracy: 0.8017589755946439
# C Value: 1, Accuracy: 0.8017589755946439
# C Value: 10, Accuracy: 0.8031983982192236
# C Value: 100, Accuracy: 0.8031978245155071
# C Value: 1000, Accuracy: 0.8029580163620299

# %%
#6
def SVM_MNIST_Tuning():
    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/mnist-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    td, tl, vd, vl = partition_mnist(training_data, training_labels)
    
    hyperperamter = 10
    clf = svm.SVC(kernel='poly', C = hyperperamter, degree = 2)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))

SVM_MNIST_Tuning()
# Out:
# C Value: 10, Accuracy: 0.9638

# %%
#6
def SVM_MNIST_Tuning():
    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/mnist-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    td, tl, vd, vl = partition_mnist(training_data, training_labels)
    
    hyperperamter = 100
    clf = svm.SVC(kernel='rbf', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    print("C Value: " + str(hyperperamter) + ", Accuracy: " + str(clf.score(vd, vl)))


SVM_MNIST_Tuning()
# Out:
# C Value: 100, Accuracy: 0.9668

# %%
#6

def results_to_csv(y_test):
    y_test = y_test.astype(int)
    df = pd.DataFrame({'Category': y_test})
    df.index += 1 # Ensures that the index starts at 1
    df.to_csv('submission.csv', index_label='Id')
    
def SVM_MNIST_Tuning():
    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/mnist-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    td, tl, vd, vl = partition_mnist(training_data, training_labels)
    
    hyperperamter = 100
    clf = svm.SVC(kernel='rbf', C = hyperperamter)

    X = td[:10000]
    y = tl[:10000]
    clf.fit(X,y)

    newdata = np.reshape(np.squeeze(test_data, axis = 1), (10000, 784))
    answer = clf.predict(newdata)
    
    results_to_csv(answer)
    


SVM_MNIST_Tuning()

# %%
def SVM_SPAM_KFOLD(Cvals):

    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/spam-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    np.random.seed(10)
    permuted_data = np.random.permutation(training_data)
    np.random.seed(10)
    permuted_labels = np.random.permutation(training_labels)

    partition_size = len(permuted_data) // 5

    set1 = permuted_data[:partition_size]
    set2 = permuted_data[partition_size : 2*partition_size]
    set3 = permuted_data[2*partition_size : 3*partition_size]
    set4 = permuted_data[3*partition_size : 4*partition_size]
    set5 = permuted_data[4*partition_size:]

    datasets = [set1, set2, set3, set4, set5]

    fullsets = [np.concatenate((set2, set3, set4, set5)),
                np.concatenate((set1, set3, set4, set5)),
                np.concatenate((set1, set2, set4, set5)),
                np.concatenate((set1, set2, set3, set5)),
                np.concatenate((set1, set2, set3, set4))]
    
    label1 = permuted_labels[:partition_size]
    label2 = permuted_labels[partition_size : 2*partition_size]
    label3 = permuted_labels[2*partition_size : 3*partition_size]
    label4 = permuted_labels[3*partition_size : 4*partition_size]
    label5 = permuted_labels[4*partition_size:]


    labels = [label1, label2, label3, label4, label5]

    fulllabels = [np.concatenate((label2, label3, label4, label5)),
                  np.concatenate((label1, label3, label4, label5)),
                  np.concatenate((label1, label2, label4, label5)),
                  np.concatenate((label1, label2, label3, label5)),
                  np.concatenate((label1, label2, label3, label4))]

    tempAccuracies = []
    finalAccuracies = []

    for c in Cvals:
        for i in range(5):
            clf = svm.SVC(kernel='linear', C = c)
            clf.fit(fullsets[i], fulllabels[i])
            tempAccuracies.append(clf.score(datasets[i], labels[i]))
        finalAccuracies.append(np.mean(tempAccuracies))
        tempAccuracies = []
    return finalAccuracies

C_values = [10]
results = SVM_SPAM_KFOLD(C_values)

for i in range(len(results)):
    print("C Value: " + str(C_values[i]) + ", Accuracy: " + str(results[i]))
# Out:
# C Value: 10, Accuracy: 0.8031983982192236

# %%
def SVM_SPAM_KFOLD(Cvals):

    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/spam-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    np.random.seed(10)
    permuted_data = np.random.permutation(training_data)
    np.random.seed(10)
    permuted_labels = np.random.permutation(training_labels)

    partition_size = len(permuted_data) // 5

    set1 = permuted_data[:partition_size]
    set2 = permuted_data[partition_size : 2*partition_size]
    set3 = permuted_data[2*partition_size : 3*partition_size]
    set4 = permuted_data[3*partition_size : 4*partition_size]
    set5 = permuted_data[4*partition_size:]

    datasets = [set1, set2, set3, set4, set5]

    fullsets = [np.concatenate((set2, set3, set4, set5)),
                np.concatenate((set1, set3, set4, set5)),
                np.concatenate((set1, set2, set4, set5)),
                np.concatenate((set1, set2, set3, set5)),
                np.concatenate((set1, set2, set3, set4))]
    
    label1 = permuted_labels[:partition_size]
    label2 = permuted_labels[partition_size : 2*partition_size]
    label3 = permuted_labels[2*partition_size : 3*partition_size]
    label4 = permuted_labels[3*partition_size : 4*partition_size]
    label5 = permuted_labels[4*partition_size:]


    labels = [label1, label2, label3, label4, label5]

    fulllabels = [np.concatenate((label2, label3, label4, label5)),
                  np.concatenate((label1, label3, label4, label5)),
                  np.concatenate((label1, label2, label4, label5)),
                  np.concatenate((label1, label2, label3, label5)),
                  np.concatenate((label1, label2, label3, label4))]

    tempAccuracies = []
    finalAccuracies = []

    for c in Cvals:
        for i in range(5):
            print(i)
            clf = svm.SVC(kernel='rbf', C = c)
            clf.fit(fullsets[i], fulllabels[i])
            tempAccuracies.append(clf.score(datasets[i], labels[i]))
            clf = None
        finalAccuracies.append(np.mean(tempAccuracies))
        tempAccuracies = []
    return finalAccuracies

C_values = [1000]
results = SVM_SPAM_KFOLD(C_values)

for i in range(len(results)):
    print("C Value: " + str(C_values[i]) + ", Accuracy: " + str(results[i]))
# Out:
# 0
# 1
# 2
# 3
# 4
# C Value: 1000, Accuracy: 0.8274069739423773

# %%
def SVM_SPAM_KFOLD(Cvals):

    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/spam-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    np.random.seed(10)
    permuted_data = np.random.permutation(training_data)
    np.random.seed(10)
    permuted_labels = np.random.permutation(training_labels)

    partition_size = len(permuted_data) // 5

    set1 = permuted_data[:partition_size]
    set2 = permuted_data[partition_size : 2*partition_size]
    set3 = permuted_data[2*partition_size : 3*partition_size]
    set4 = permuted_data[3*partition_size : 4*partition_size]
    set5 = permuted_data[4*partition_size:]

    datasets = [set1, set2, set3, set4, set5]

    fullsets = [np.concatenate((set2, set3, set4, set5)),
                np.concatenate((set1, set3, set4, set5)),
                np.concatenate((set1, set2, set4, set5)),
                np.concatenate((set1, set2, set3, set5)),
                np.concatenate((set1, set2, set3, set4))]
    
    label1 = permuted_labels[:partition_size]
    label2 = permuted_labels[partition_size : 2*partition_size]
    label3 = permuted_labels[2*partition_size : 3*partition_size]
    label4 = permuted_labels[3*partition_size : 4*partition_size]
    label5 = permuted_labels[4*partition_size:]


    labels = [label1, label2, label3, label4, label5]

    fulllabels = [np.concatenate((label2, label3, label4, label5)),
                  np.concatenate((label1, label3, label4, label5)),
                  np.concatenate((label1, label2, label4, label5)),
                  np.concatenate((label1, label2, label3, label5)),
                  np.concatenate((label1, label2, label3, label4))]

    tempAccuracies = []
    finalAccuracies = []

    for c in Cvals:
        for i in range(5):
            print(i)
            clf = svm.SVC(kernel='rbf', C = c)
            clf.fit(fullsets[i], fulllabels[i])
            tempAccuracies.append(clf.score(datasets[i], labels[i]))
        finalAccuracies.append(np.mean(tempAccuracies))
        tempAccuracies = []
    return finalAccuracies

C_values = [1000]
results = SVM_SPAM_KFOLD(C_values)

for i in range(len(results)):
    print("C Value: " + str(C_values[i]) + ", Accuracy: " + str(results[i]))
# Out:
# 0
# 1
# 2
# 3
# 4
# C Value: 1000, Accuracy: 0.8513791837343522

# %%
#6

def results_to_csv(y_test):
    y_test = y_test.astype(int)
    df = pd.DataFrame({'Category': y_test})
    df.index += 1 # Ensures that the index starts at 1
    df.to_csv('submission.csv', index_label='Id')
    
def SVM_SPAM_KFOLD_Answer(Cvals):

    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/spam-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    np.random.seed(10)
    permuted_data = np.random.permutation(training_data)
    np.random.seed(10)
    permuted_labels = np.random.permutation(training_labels)

    partition_size = len(permuted_data) // 5

    set1 = permuted_data[:partition_size]
    set2 = permuted_data[partition_size : 2*partition_size]
    set3 = permuted_data[2*partition_size : 3*partition_size]
    set4 = permuted_data[3*partition_size : 4*partition_size]
    set5 = permuted_data[4*partition_size:]

    datasets = [set1, set2, set3, set4, set5]

    fullsets = [np.concatenate((set2, set3, set4, set5)),
                np.concatenate((set1, set3, set4, set5)),
                np.concatenate((set1, set2, set4, set5)),
                np.concatenate((set1, set2, set3, set5)),
                np.concatenate((set1, set2, set3, set4))]
    
    label1 = permuted_labels[:partition_size]
    label2 = permuted_labels[partition_size : 2*partition_size]
    label3 = permuted_labels[2*partition_size : 3*partition_size]
    label4 = permuted_labels[3*partition_size : 4*partition_size]
    label5 = permuted_labels[4*partition_size:]


    labels = [label1, label2, label3, label4, label5]

    fulllabels = [np.concatenate((label2, label3, label4, label5)),
                  np.concatenate((label1, label3, label4, label5)),
                  np.concatenate((label1, label2, label4, label5)),
                  np.concatenate((label1, label2, label3, label5)),
                  np.concatenate((label1, label2, label3, label4))]

    tempAccuracies = []
    finalAccuracies = []

    for c in Cvals:
        for i in range(5):
            print(i)
            clf = svm.SVC(kernel='rbf', C = c)
            clf.fit(fullsets[i], fulllabels[i])
            tempAccuracies.append(clf.score(datasets[i], labels[i]))
        finalAccuracies.append(np.mean(tempAccuracies))
        tempAccuracies = []
    
    print(test_data.shape)
    answer = clf.predict(test_data)
    
    results_to_csv(answer)
    

C_values = [1000]
SVM_SPAM_KFOLD_Answer(C_values)
# Out:
# 0
# 1
# 2
# 3
# 4
# (1000, 46)

# %%
def SVM_CIFAR10():
    data = np.load("/Users/Dom/Desktop/CS189/hw1/data/cifar10-data.npz")
    test_data = data["test_data"]
    training_data = data["training_data"]
    training_labels = data["training_labels"]

    td, tl, vd, vl = partition_cifar10(training_data, training_labels)
    clf = svm.SVC(kernel='poly', degree = 2, C=1)

    X = td[:5000]
    y = tl[:5000]
    clf.fit(X,y)

    print(clf.score(vd, vl))

    answer = clf.predict(test_data)
    
    results_to_csv(answer)


SVM_CIFAR10()
# Out:
# 0.4076

# %%
women = .5 
fertility = 1.64
expectancy = 60
people_per_age = []
growth_rates = []
years = [1 + i for i in range(61)]

for i in range(60):
    people_per_age.append(np.random.randint(30000, 100000))

for i in range(200):
    average_women_birthing = (sum((people_per_age[15:51])) * women) / len(people_per_age[15:51])
    people_per_age = [average_women_birthing * fertility] + people_per_age
    if (len(people_per_age) > expectancy):
        people_per_age.pop()

for i in range(61):
    startpop =  sum(people_per_age)
    average_women_birthing = (sum((people_per_age[15:51])) * women) / len(people_per_age[15:51])
    people_per_age = [average_women_birthing * fertility] + people_per_age
    if (len(people_per_age) > expectancy):
        people_per_age.pop()
    endpop = sum(people_per_age)
    if not expectancy >= 99:
        expectancy += 1
    growth_rates.append((endpop/startpop) - 1)

plt.plot(years, growth_rates)
